# %%
import hockey.hockey_env as h_env
env = h_env.HockeyEnv() 
obs_agent2 = env.obs_agent_two() # initiate two agents

# %%
obs_agent2
# Out:
# array([-3.        , -0.        ,  0.        , -0.        , -0.        ,
#         0.        ,  3.        , -0.        ,  0.        , -0.        ,
#        -0.        ,  0.        ,  1.61180949, -0.64978027, -0.        ,
#        -0.        ,  0.        ,  0.        ])

# %%
import numpy as np
a1 = np.random.uniform(-1, 1, 4).tolist()
a2 = np.random.uniform(-1, 1, 4).tolist()

# %%
new_obs1, r, d, t, info = env.step(np.hstack([a1, a2]))

# %%
d - 1
# Out:
# -1

# %%
import torch

# %%
done = False
done_t = torch.tensor(done, dtype=torch.bool)

# %%
while not done_t:
    done_t  = True

# %%
x = torch.rand(size = (4,1))
y = torch.rand(size = (4,1))
reward = torch.rand(size = (4,1))
done_t = torch.tensor(done, dtype=torch.bool)
done = np.array([True,False,True,True])
done = torch.from_numpy(done.astype(np.float32))

target_Q = reward + 0.99 * (1 - done) * torch.min(x, y)
# Out:
# /var/folders/z4/0m49679n1xd2nv8l_dt8zz880000gn/T/ipykernel_19393/4270978283.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   done_t = torch.tensor(done, dtype=torch.bool)

# %%
done
# Out:
# tensor([1., 0., 1., 1.])

# %%
self.dones = np.zeros((max_size, 1))
